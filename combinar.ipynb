# %%
import pandas as pd
import openpyxl

# %%
df1 = pd.read_excel('Clientes Combinados.xlsx')
df2 = pd.read_excel('CEDULA 3ER Anticipo de OCTUBRE 2025 PREPARADO.xlsx')

# %%
# Asegurar que no haya espacios extra en los nombres de columnas
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()

# Copiar los nombres originales en nuevas columnas antes de normalizar
df1['NOMBRE_ORIGINAL'] = df1['NOMBRE_ORIGINAL']
df2['NOMBRE_COMPLETO_ORIGINAL'] = df2['NOMBRE COMPLETO']

# Función para normalizar nombres (maneja valores nulos)
def normalizar_nombre(nombre):
    if pd.isna(nombre):  # Evita errores con NaN
        return ''
    return ' '.join(sorted(nombre.split()))

# Aplicar normalización en las nuevas columnas
df1['NOMBRE_NORMALIZADO'] = df1['NOMBRE_ORIGINAL'].apply(normalizar_nombre)
df2['NOMBRE_NORMALIZADO'] = df2['NOMBRE_COMPLETO_ORIGINAL'].apply(normalizar_nombre)

# Hacer el merge en la columna normalizada
df_merged = df1.merge(df2, on='NOMBRE_NORMALIZADO', how='inner')

# Ver resultado
print(df_merged)

# Seleccionar solo algunas columnas de df_merged y guardarlas en un nuevo DataFrame
columnas_seleccionadas = ['ZONA_x','N_EMPRESARIO','NOMBRE_ORIGINAL', 'RFC', 'TOTAL DIAS','COSTO X DIA','ANTICIPO 4','IVA 16%','RETENCION AL IVA 10.67%','RETENCION ISR 1.25%','TOTAL ANTICIPO 4','Corresponsalías y recargas']
#columnas_seleccionadas = ['ZONA_x','N_EMPRESARIO','NOMBRE_ORIGINAL', 'RFC', 'TOTAL DIAS','COSTO X DIA','ANTICIPO 4','IVA 16%','RETENCION AL IVA 10.67%','RETENCION ISR 1.25%','TOTAL','Corresponsalías y recargas']
df_seleccionado = df_merged[columnas_seleccionadas]
df_seleccionado = df_seleccionado.assign(Anticipo_logrado='', Bono_Servicio_logrado='',Anticipo_Cargado='', Bono_Servicio_Cargado='')
# **Exportar a Excel**
archivo_salida = 'datos_cruzados 3er Octubre.xlsx'
df_seleccionado.to_excel(archivo_salida, index=False, engine='openpyxl')
# Out:
#             ZONA_x  N_EMPRESARIO                  NOMBRE_ORIGINAL  \
# 0            NORTE        115266            YEREMY PICHARDO MEJIA
# 1            NORTE        114414          XIMENA POSADAS FAJARDO
# 2            NORTE        114975          WENDY CABANILLAS CASTRO
# 3    CTRO 1 NORTE         111566             VIRGINIA MORA PEREZ
# 4    CTRO 1 NORTE         111566             VIRGINIA MORA PEREZ
# ..             ...           ...                              ...
# 129            NaN        115657            ANA KAREN CHINO VELEZ
# 130            NaN        115665   MARIA DEL CARMEN OSORIO SUAREZ
# 131            NaN        115680         MARGARITA AGUSTIN MIGUEL
# 132            NaN        115681  BRAYAN RODRIGO CALDERON HUITRON
# 133            NaN        115684     INDIRA PAOLA CAMACHO LUEVANO
#
#                   RFC               NOMBRE_NORMALIZADO         SOCIEDAD  \
# 0       PIMY920809NF4            MEJIA PICHARDO YEREMY  EK CONVENIENCIA
# 1    POFX020816449              FAJARDO POSADAS XIMENA  EK CONVENIENCIA
# 2       CACW7602096V0          CABANILLAS CASTRO WENDY  EK CONVENIENCIA
# 3       MOPV870305588              MORA PEREZ VIRGINIA  EK CONVENIENCIA
# 4       MOPV870305588              MORA PEREZ VIRGINIA  EK CONVENIENCIA
# ..                ...                              ...              ...
# 129     CIVA0302234H7            ANA CHINO KAREN VELEZ  EK CONVENIENCIA
# 130     OOSC0208081W3   CARMEN DEL MARIA OSORIO SUAREZ  EK CONVENIENCIA
# 131     AUMM9007207TA         AGUSTIN MARGARITA MIGUEL  EK CONVENIENCIA
# 132     CAHB9610187I0  BRAYAN CALDERON HUITRON RODRIGO  EK CONVENIENCIA
# 133     CALI8805142X9     CAMACHO INDIRA LUEVANO PAOLA  EK CONVENIENCIA
#
#      REGION             ZONA   ESTATUS  NO. DE DETERMINANTE  ...  \
# 0    CENTRO            NORTE   TITULAR                  992  ...
# 1    CENTRO            NORTE   TITULAR                 7190  ...
# 2    CENTRO            NORTE   TITULAR                 7136  ...
# 3    CENTRO  CENTRO 1 NORTE    TITULAR                 7121  ...
# 4    CENTRO  CENTRO 1 NORTE   ASIGNADA                 7520  ...
# ..      ...              ...       ...                  ...  ...
# 129  CENTRO  PONIENTE TOLUCA   TITULAR                 7130  ...
# 130  CENTRO            NORTE   TITULAR                 7339  ...
# 131  CENTRO  CENTRO 1 NORTE    TITULAR                  146  ...
# 132  CENTRO   SUR CUERNAVACA   TITULAR                 7386  ...
# 133  CENTRO   SUR CUERNAVACA   TITULAR                 4407  ...
#
#     FALTANTE DE EFECTIVO FALTANTE DE INVENTARIO  FONDO DE INVENTARIO.1  \
# 0                   0.00                 2000.0                    250
# 1                3500.00                    0.0                      0
# 2                   0.00                    0.0                    250
# 3                   0.00                    0.0                      0
# 4                   0.00                    0.0                      0
# ..                   ...                    ...                    ...
# 129              1284.80                    0.0                    250
# 130                 0.00                    0.0                      0
# 131                22.37                    0.0                    250
# 132                 0.00                    0.0                    250
# 133                 0.00                    0.0                    250
#
#      FONDO FIJO  TOTAL DEPOSITO FOLIO FACTURA ANTICIPO 4  \
# 0           0.0       5115.8625                      NaN
# 1           0.0       3875.8625                      NaN
# 2           0.0       7151.8625                      NaN
# 3           NaN       7349.8625                      NaN
# 4           NaN       7330.8625                      NaN
# ..          ...             ...                      ...
# 129         0.0       5809.0625                      NaN
# 130      1000.0       8330.8625                      NaN
# 131         NaN       9133.7075                      NaN
# 132         0.0       9144.0775                      NaN
# 133         0.0       9116.0775                      NaN
#
#      PAGO DECLARACION ANUAL  PAGO SEMANAL COMENTARIOS  \
# 0                       0.0           0.0         NaN
# 1                       0.0           0.0         NaN
# 2                       0.0           0.0         NaN
# 3                       0.0           0.0         NaN
# 4                       0.0           0.0         NaN
# ..                      ...           ...         ...
# 129                     0.0           0.0         NaN
# 130                     0.0           0.0         NaN
# 131                     0.0           0.0         NaN
# 132                     NaN           0.0         NaN
# 133                     NaN           0.0         NaN
#
#             NOMBRE_COMPLETO_ORIGINAL
# 0              PICHARDO MEJIA YEREMY
# 1             POSADAS FAJARDO XIMENA
# 2            CABANILLAS CASTRO WENDY
# 3               MORA PEREZ VIRGINIA
# 4               MORA PEREZ VIRGINIA
# ..                               ...
# 129            CHINO VELEZ ANA KAREN
# 130   OSORIO SUAREZ MARIA DEL CARMEN
# 131        AGUSTIN MIGUEL MARGARITA
# 132  CALDERON HUITRON BRAYAN RODRIGO
# 133     CAMACHO LUEVANO INDIRA PAOLA
#
# [134 rows x 39 columns]
